# %% [markdown]
# # Terrestrial water storage changes derived form GRACE
#
#
# Author:
#
# To use this notebook, the shxarray package should be installed from https://github.com/ITC-Water-Resources/shxarray or from https://pypi.org/project/shxarray/
#
# The data used in this example is from ITSG Level-2 datasets https://www.tugraz.at/institute/ifg/downloads/gravity-field-models/itsg-grace2018#c194128
#
#
# Computing Terrestrial Water Storage change:
#
# Stokes coefficients from the GRACE solutions can be converted to an equivalent water height, but several processing steps are often needed to obtain good results. The steps are described as below:
#
# * Obtain time-anomalies by subtracting a static gravity field from the monthly solutions (more details about the static gravity filed models: https://icgem.gfz-potsdam.de/tom_longtime and https://ggos.org/item/global-gravity-field-models/)
# * *To do:* Substitute the less accurate degree 2 coefficients with alternatives from a Satellite Laser Ranging solution
# * *To do:* Add degree 1 variations, which are needed to resolve for the Earth's wobbly around it's center of mass
# * Filter the coefficients to remove high degree noise
# * Map (spherical harmonic synthesis) the results to a geographical area

# %%
change to zip file format

# %% [markdown]
# purpose of the exrecise
# 3 learning outcomes of the tutorial
# Water variable from earth observation - tws
# 2 versions
# assign a certain weight to each step

# %% [markdown]
# %env OPENBLAS_NUM_THREADS=4

# %% [markdown]
# #Optionally enable autoreloading for development purposes. Note that this does not automagically reload the binary extensions
# %load_ext autoreload
# %autoreload 2
# #also supress some warnings from pandas
# import warnings
# warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import xarray as xr
import numpy as np
import os
import matplotlib.pyplot as plt
import gzip
import shxarray
import pandas as pd

# %% [markdown]
# Read monthly solutions Stokes coefficients form directory path

# %%
# datadir = '~/shared/Waterflux/data/ITSG_grace2018/monthly/monthly_n96'

# Using my session data dir
datadir = '../shared/Waterflux/data/ITSG_grace2018/monthly/monthly_n96'

datadir = os.path.expanduser(datadir)

# %%
def load_icgem_files(datadir):

    gsm = []
    files = os.listdir(datadir)

    for file in files:
        file_path = os.path.join(datadir, file)
        gsm.append(xr.open_dataset(file_path, engine="icgem")) ## Depending on the gravitational spherical harmonic model, the engine can be = "gsmv6"
        
    dsgsm = xr.concat(gsm, dim="time")
    dsgsm = dsgsm.sortby('time')

    return dsgsm

# %%
ds = load_icgem_files(datadir)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 162, nm: 9409)
# Coordinates:
#   * nm       (nm) object MultiIndex
#   * n        (nm) int64 0 1 1 1 2 2 2 2 2 3 3 ... 96 96 96 96 96 96 96 96 96 96
#   * m        (nm) int64 0 0 1 -1 0 1 -1 2 -2 ... -92 93 -93 94 -94 95 -95 96 -96
#   * time     (time) datetime64[ns] 2002-04-15T12:00:00 ... 2017-06-15T12:00:00
# Data variables:
#     cnm      (time, nm) float64 1.0 0.0 0.0 ... 2.452e-10 -2.245e-09 1.527e-09
#     sigcnm   (time, nm) float64 0.0 0.0 0.0 ... 5.098e-11 2.906e-11 2.797e-11
# Attributes:
#     nmaxfile:   96
#     nmax:       96
#     format:     icgem
#     norm:       fully_normalized
#     gm:         398600441500000.0
#     re:         6378136.3
#     modelname:  ITSG-Grace2018_n96_2013-12

# %% [markdown]
# # Read the time-invariable static gravity field data

# %%
# datadir = '~/shared/Waterflux/data/ITSG_grace2018/monthly/static'

# Using my session data dir
datadir = '../shared/Waterflux/data/ITSG_grace2018/monthly/static'


datadir = os.path.expanduser(datadir)
name= "ITSG-Grace2018s.gfc"
file_path = os.path.join(datadir, name)
dsstatic = xr.open_dataset(file_path, engine="icgem" ,drop_variables=["sigcnm"])
dsstatic
# Out:
# <xarray.Dataset>
# Dimensions:  (nm: 40401)
# Coordinates:
#   * nm       (nm) object MultiIndex
#   * n        (nm) int64 0 1 1 1 2 2 2 2 2 ... 200 200 200 200 200 200 200 200
#   * m        (nm) int64 0 0 1 -1 0 1 -1 2 ... -197 198 -198 199 -199 200 -200
# Data variables:
#     cnm      (nm) float64 ...
# Attributes:
#     nmaxfile:   200
#     nmax:       200
#     format:     icgem
#     norm:       fully_normalized
#     gm:         398600441500000.0
#     re:         6378136.3
#     modelname:  ITSG-Grace2018s

# %%
ds["dcnm"]=ds.cnm-dsstatic.cnm
ds.sel(n=2,m=0)
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 162)
# Coordinates:
#     nm       object (2, 0)
#     n        int64 2
#     m        int64 0
#   * time     (time) datetime64[ns] 2002-04-15T12:00:00 ... 2017-06-15T12:00:00
# Data variables:
#     cnm      (time) float64 -0.0004842 -0.0004842 ... -0.0004842 -0.0004842
#     sigcnm   (time) float64 1.541e-11 3.199e-11 ... 6.207e-11 7.373e-11
#     dcnm     (time) float64 1.923e-10 1.174e-10 ... -1.23e-10 1.329e-10
# Attributes:
#     nmaxfile:   96
#     nmax:       96
#     format:     icgem
#     norm:       fully_normalized
#     gm:         398600441500000.0
#     re:         6378136.3
#     modelname:  ITSG-Grace2018_n96_2013-12

# %% [markdown]
# # Helper class which aids in extracing the gzipped data files from the Tar file without the need to extract the data to the disk
# class TarExtracter:
#     def __init__(self,tararchive):
#         """ Opens a tararchive and keep its open acces point available to functions within this class"""
#         self.tarar=tarfile.open(os.path.join(datadir,tararchive),'r:gz')
#     def getmember(self,member):
#         """Extract a specific (gzipped) member from an open archive, and return an open file object"""
#         tarfileobj=self.tarar.extractfile(member)
#         return gzip.open(tarfileobj)
#     def close(self):
#         self.tarar.close()
#
# import tarfile

# %%
nmax=ds.sh.nmax
nmax
# Out:
# 96

# %%
def load_icgem_files(datadir):

    gsm = []
    deg1_terms = []
    term_c20 = []
    files = os.listdir(datadir)

    for file in files:
        file_path = os.path.join(datadir, file)
        if "c20" in file:
            term_c20.append(xr.open_dataset(file_path, engine="gsmv6"))
        elif "degree1" in file:
            deg1_terms.append(xr.open_dataset(file_path, engine="gsmv6"))
                
            
        
    # dsgsm = xr.concat(gsm, dim="time")
    # dsgsm = dsgsm.sortby('time')


    if output_type == deg1:
        return xr.concat(deg1, dim="time")
    elif output_type == c20:
        return xr.concat(c20, dim="time")

# %%
# Define your directory and file
datadir = os.path.expanduser('../shared/Waterflux/data/ITSG_grace2018/monthly/monthly_background')
file = "model_c20_2014-05.gfc"
file_path = os.path.join(datadir, file)

ds1 = xr.open_dataset(file_path, engine="icgem")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [12], line 6
#       3 file = "model_c20_2014-05.gfc"
#       4 file_path = os.path.join(datadir, file)
# ----> 6 ds1 = xr.open_dataset(file_path, engine="icgem")
#
# File ~/.local/lib/python3.8/site-packages/xarray/backends/api.py:541, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, backend_kwargs, **kwargs)
#     529 decoders = _resolve_decoders_kwargs(
#     530     decode_cf,
#     531     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     537     decode_coords=decode_coords,
#     538 )
#     540 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 541 backend_ds = backend.open_dataset(
#     542     filename_or_obj,
#     543     drop_variables=drop_variables,
#     544     **decoders,
#     545     **kwargs,
#     546 )
#     547 ds = _dataset_from_backend_dataset(
#     548     backend_ds,
#     549     filename_or_obj,
#    (...)
#     557     **kwargs,
#     558 )
#     559 return ds
#
# File ~/.local/lib/python3.8/site-packages/shxarray/io/shiobackend.py:18, in ICGEMBackEntryPoint.open_dataset(self, filename_or_obj, drop_variables)
#      17 def open_dataset(self,filename_or_obj,*,drop_variables=None):
# ---> 18     dsout=readIcgem(filename_or_obj)
#      19     if drop_variables is not None:
#      20         dsout=dsout.drop_vars(drop_variables)
#
# File ~/.local/lib/python3.8/site-packages/shxarray/io/icgem.py:113, in readIcgem(fileobj, nmaxstop)
#     110 m=int(lnspl[2])
#     112 cnm[ncount]=float(lnspl[3])
# --> 113 sigcnm[ncount]=float(lnspl[5])
#     114 nm.append((n,m))
#     115 ncount+=1
#
# IndexError: list index out of range

# %%
# Read the file as text and parse to dataframe

# File path to model_c20_2014-05.gfc
file_loc = file_path # defined above

# Initialize lists to store metadata and data
metadata = {}
data = []

with open(file_loc, 'r') as f:
    for line in f:
        # Check for the description and store as attributes
        
        if line.startswith("modelname"):
            metadata['modelname'] = line.split()[1]
        elif line.startswith("product_type"):
            metadata['product_type'] = line.split()[1]
        elif line.startswith("earth_gravity_constant"):
            metadata['earth_gravity_constant'] = float(line.split()[1])
        elif line.startswith("radius"):
            metadata['radius'] = float(line.split()[1])
        elif line.startswith("max_degree"):
            metadata['max_degree'] = int(line.split()[1])
        elif line.startswith("norm"):
            metadata['norm'] = line.split()[1]
        elif line.startswith("errors"):
            metadata['errors'] = line.split()[1]
        # Parse data section after "key" line
        elif line.startswith("gfc"):
            parts = line.split()
            n = int(parts[1])
            m = int(parts[2])
            c = float(parts[3])
            s = float(parts[4])
            data.append([n, m, c, s])

# Convert data to a DataFrame
df = pd.DataFrame(data, columns=["n", "m", "cnm", "sigcnm"])

# Creating multindex coordinate nm but doesn't seem to work
df.index = pd.MultiIndex.from_frame(df[["n", "m"]], names=["n", "m"])

# Drop the n and m columns since they’re now in the index
df = df.drop(columns=["n", "m"])

# Convert DataFrame to xarray Dataset with a single "nm" dimension using the MultiIndex - but this doesn't work yet
dsc = df.to_xarray()

# Add metadata as attributes to the Dataset
dsc.attrs.update(metadata)

# Print the xarray Dataset
print(dsc)
# Out:
# <xarray.Dataset>
# Dimensions:  (n: 3, m: 3)
# Coordinates:
#   * n        (n) int64 0 1 2
#   * m        (m) int64 0 1 2
# Data variables:
#     cnm      (n, m) float64 0.0 nan nan 0.0 0.0 nan -0.0004842 0.0 0.0
#     sigcnm   (n, m) float64 0.0 nan nan 0.0 0.0 nan 0.0 0.0 0.0
# Attributes:
#     modelname:               model_c20_2014-05
#     product_type:            gravity_field
#     earth_gravity_constant:  398600441500000.0
#     radius:                  6378136.3
#     max_degree:              2
#     norm:                    fully_normalized
#     errors:                  no

# %%
# c20 xarray
dsc
# Out:
# <xarray.Dataset>
# Dimensions:  (n: 3, m: 3)
# Coordinates:
#   * n        (n) int64 0 1 2
#   * m        (m) int64 0 1 2
# Data variables:
#     cnm      (n, m) float64 0.0 nan nan 0.0 0.0 nan -0.0004842 0.0 0.0
#     sigcnm   (n, m) float64 0.0 nan nan 0.0 0.0 nan 0.0 0.0 0.0
# Attributes:
#     modelname:               model_c20_2014-05
#     product_type:            gravity_field
#     earth_gravity_constant:  398600441500000.0
#     radius:                  6378136.3
#     max_degree:              2
#     norm:                    fully_normalized
#     errors:                  no

# %% [markdown]
# # (To Do) Replace degree one coefficients and c20 from
# https://podaac.jpl.nasa.gov/announcements/2018-07-16_UTCSR/JPL_GRACE_Level-2_RL06_datasets_release

# %% [markdown]
# # Calculate terrestrial water storage in spectral domain

# %%
#  nmax=shindex.n.max().item()
#         nminsup= self._dsiso.n.min().item() 
#         nmaxsup= self._dsiso.n.max().item()
#         if nmin < nminsup or  nmax > nmaxsup:
#             raise RuntimeError("Requested kernel operation is only supported for degrees {nminsup} < = n <= {nmaxsup}")



dsn=ds.cnm-dsc.cnm
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [95], line 9
#       1 #  nmax=shindex.n.max().item()
#       2 #         nminsup= self._dsiso.n.min().item()
#       3 #         nmaxsup= self._dsiso.n.max().item()
#       4 #         if nmin < nminsup or  nmax > nmaxsup:
#       5 #             raise RuntimeError("Requested kernel operation is only supported for degrees {nminsup} < = n <= {nmaxsup}")
# ----> 9 dsn=ds.cnm-dsc.cnm
#
# File ~/.local/lib/python3.8/site-packages/xarray/core/_typed_ops.py:209, in DataArrayOpsMixin.__sub__(self, other)
#     208 def __sub__(self, other):
# --> 209     return self._binary_op(other, operator.sub)
#
# File ~/.local/lib/python3.8/site-packages/xarray/core/dataarray.py:4362, in DataArray._binary_op(self, other, f, reflexive)
#    4360 if isinstance(other, DataArray):
#    4361     align_type = OPTIONS["arithmetic_join"]
# -> 4362     self, other = align(self, other, join=align_type, copy=False)  # type: ignore
#    4363 other_variable = getattr(other, "variable", other)
#    4364 other_coords = getattr(other, "coords", None)
#
# File ~/.local/lib/python3.8/site-packages/xarray/core/alignment.py:797, in align(join, copy, indexes, exclude, fill_value, *objects)
#     601 """
#     602 Given any number of Dataset and/or DataArray objects, returns new
#     603 objects with aligned indexes and dimension sizes.
#    (...)
#     787
#     788 """
#     789 aligner = Aligner(
#     790     objects,
#     791     join=join,
#    (...)
#     795     fill_value=fill_value,
#     796 )
# --> 797 aligner.align()
#     798 return aligner.results
#
# File ~/.local/lib/python3.8/site-packages/xarray/core/alignment.py:583, in Aligner.align(self)
#     581 self.find_matching_indexes()
#     582 self.find_matching_unindexed_dims()
# --> 583 self.assert_no_index_conflict()
#     584 self.align_indexes()
#     585 self.assert_unindexed_dim_sizes_equal()
#
# File ~/.local/lib/python3.8/site-packages/xarray/core/alignment.py:326, in Aligner.assert_no_index_conflict(self)
#     322 if dup:
#     323     items_msg = ", ".join(
#     324         f"{k!r} ({v} conflicting indexes)" for k, v in dup.items()
#     325     )
# --> 326     raise ValueError(
#     327         "cannot re-index or align objects with conflicting indexes found for "
#     328         f"the following {msg}: {items_msg}\n"
#     329         "Conflicting indexes may occur when\n"
#     330         "- they relate to different sets of coordinate and/or dimension names\n"
#     331         "- they don't have the same type\n"
#     332         "- they may be used to reindex data along common dimensions"
#     333     )
#
# ValueError: cannot re-index or align objects with conflicting indexes found for the following coordinates: 'nm' (2 conflicting indexes)
# Conflicting indexes may occur when
# - they relate to different sets of coordinate and/or dimension names
# - they don't have the same type
# - they may be used to reindex data along common dimensions

# %%
ds.var
# Out:
# <bound method DatasetAggregations.var of <xarray.Dataset>
# Dimensions:  (L: 201, M: 201)
# Coordinates:
#   * L        (L) int64 0 1 2 3 4 5 6 7 8 ... 192 193 194 195 196 197 198 199 200
#   * M        (M) int64 0 1 2 3 4 5 6 7 8 ... 192 193 194 195 196 197 198 199 200
# Data variables:
#     C        (L, M) float64 1.0 nan nan nan ... -1.506e-09 2.7e-10 1.598e-10
#     S        (L, M) float64 0.0 nan nan nan ... 9.425e-10 -7.361e-10 1.957e-10
# Attributes:
#     modelname:               ITSG-Grace2018s
#     product_type:            gravity_field
#     earth_gravity_constant:  398600441500000.0
#     radius:                  6378136.3
#     max_degree:              200
#     norm:                    fully_normalized
#     errors:                  formal>

# %%
datws=ds.dcnm.sh.tws()
display(datws)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [56], line 1
# ----> 1 datws=ds.dcnm.sh.tws()
#       2 display(datws)
#
# File ~/.local/lib/python3.8/site-packages/xarray/core/common.py:278, in AttrAccessMixin.__getattr__(self, name)
#     276         with suppress(KeyError):
#     277             return source[name]
# --> 278 raise AttributeError(
#     279     f"{type(self).__name__!r} object has no attribute {name!r}"
#     280 )
#
# AttributeError: 'Dataset' object has no attribute 'dcnm'

# %% [markdown]
# # Calculate terrestrial water storage change in spatial domain globally

# %%
dsgrd=datws.sh.synthesis().to_dataset(name="tws")
islice=0
dsgrd.tws[:,:,islice].plot(vmin=-0.5,vmax=0.5)
dsgrd
lats = dsgrd['lat'].values
lons = dsgrd['lon'].values

# %% [markdown]
# # Apply filters
